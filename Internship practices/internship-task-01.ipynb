# %% [markdown]
# Task: Load data into pandas, clean it (remove nulls), and plot a bar graph of article categories.
#
# I’ll demonstrate these actions using train.csv from the famous Kaggle Titanic dataset.
# Specifically, I will directly remove rows with missing values and plot a bar graph showing the distribution of passenger classes (Pclass).

# %%
# Step 1: Load Titanic train data
import pandas as pd

df = pd.read_csv('../titanic/train.csv')
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# Step 2: Drop rows with missing values
df_cleaned = df.dropna()
df_cleaned.head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# Step 3: Plot bar chart of passenger classes (Pclass)
df_cleaned['Pclass'].value_counts().sort_index().plot(
    kind='bar',
    title='PClass Distribution (Cleaned)',
    xlabel='Pclass',
    ylabel='Count',
)
# Out:
# <Axes: title={'center': 'PClass Distribution (Cleaned)'}, xlabel='Pclass', ylabel='Count'>

# %% [markdown]
# # Please note: This bar plot is not statistically accurate, as the missing values in the dataset are not randomly distributed — they are predominantly clustered in the lower passenger classes. This task is intended solely to demonstrate my practical skills in Python and Pandas, not to perform a data analysis.
